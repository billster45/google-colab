# %% [markdown]
# <a href="https://colab.research.google.com/github/billster45/google-colab/blob/master/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.2     ✔ purrr   0.3.4
# ✔ tibble  3.0.1     ✔ dplyr   1.0.0
# ✔ tidyr   1.1.0     ✔ stringr 1.4.0
# ✔ readr   1.3.1     ✔ forcats 0.5.0
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %%
install.packages("janitor")
install.packages("mlbench")
library(mlbench)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
ggplot2::txhousing %>%
 ggplot2::ggplot() +
 ggplot2::aes(x = year, y = sales) +
 ggplot2::geom_point()
# Out:
# Warning message:
# “Removed 568 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# # New section

# %% [markdown]
# # New section
